# %%
from scipy.special import gamma, factorial
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special

nu_0=0.5#m=0,\alpha=pi/4
sMax=100
#x=np.exp(np.arange(-8,-5,0.01))
x=np.arange(1,30,0.01)
#x=np.append(x1,x2)
Error=1e-20

amplitude=np.sqrt(2*nu_0*np.tanh(nu_0*np.pi*0.5)/np.pi)
multiplication=1
DF_1j_nu_0=0
for s in np.arange(0,sMax+1):
    multiplication=multiplication*(s**2+nu_0**2)
    phi_nu_0_s=np.angle(gamma(1+s+1j*nu_0))
    derivative=-nu_0/2*np.sin(nu_0*np.log(x/2)-phi_nu_0_s)+s*np.cos(nu_0*np.log(x/2)-phi_nu_0_s)
    Sum=(-1)**s*(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)*2/x*derivative
    DF_1j_nu_0=DF_1j_nu_0+Sum
    if(np.size(Sum)==1):
            Sum=np.append(Sum,0)
    if(max(abs(Sum))<Error):
        break
if(s==sMax):
    print("DF_1j_nu_0 don't converge")
DF_1j_nu_0=amplitude*DF_1j_nu_0

print(sMax)
print(s)
plt.plot(x,DF_1j_nu_0,label='$dF_{0.5i}(x)/dx$')
plt.plot(x,-special.jn(1,x),label='$dJ_{0}(x)dx$')
#plt.plot(x,-1/2/x,'r',label='1/2x')
plt.legend(prop={"size":16})
plt.xlabel('x',fontsize=16)
plt.ylabel('Special Functions',fontsize=16)
# Out:
# 100
# 59
# Text(0, 0.5, 'Special Functions')

# %%
from scipy.special import gamma, factorial
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special

nu_0=0.5#m=0,\alpha=pi/4
sMax=100

x1=np.exp(np.arange(-1,0.1,0.01))
x2=np.arange(1,20,0.01)
x=np.append(x1,x2)
Error=1e-20

amplitude=np.sqrt(2*nu_0*np.tanh(nu_0*np.pi*0.5)/np.pi)
multiplication=1
DF_1j_nu_0=0
for s in np.arange(0,sMax+1):
    multiplication=multiplication*(s**2+nu_0**2)
    phi_nu_0_s=np.angle(gamma(1+s+1j*nu_0))
    derivative=-nu_0/2*np.sin(nu_0*np.log(x/2)-phi_nu_0_s)+s*np.cos(nu_0*np.log(x/2)-phi_nu_0_s)
    Sum=(-1)**s*(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)*2/x*derivative
    DF_1j_nu_0=DF_1j_nu_0+Sum
    if(np.size(Sum)==1):
            Sum=np.append(Sum,0)
    if(max(abs(Sum))<Error):
        break
if(s==sMax):
    print("DF_1j_nu_0 don't converge")
DF_1j_nu_0=amplitude*DF_1j_nu_0

print(sMax)
print(s)

fig = plt.figure()
fig.set_size_inches(8,6)

left, bottom, width, height = 0.15,0.15,0.8,0.8
ax1 = fig.add_axes([left,bottom,width,height])
ax1.plot(x,DF_1j_nu_0,label='$dF_{0.5i}(x)/dx$')
ax1.plot(x,-special.jn(1,x),label='$dJ_{0}(x)/dx$')
ax1.legend(prop={"size":16},loc='lower right')
ax1.set_xlabel('x',fontsize=16)
ax1.set_ylabel('Functions',fontsize=16)
ax1.set_ylim([-1,2.2])
ax1.tick_params(labelsize=12)

left, bottom, width, height = 0.32,0.53,0.4,0.4
ax2 = fig.add_axes([left,bottom,width,height])
ax2.plot(x,DF_1j_nu_0)
#ax2.plot(x,-special.jn(1,x))
ax2.plot(x,2/x,'r',label=r'$2/x$')
ax2.set_xlabel('x',fontsize=16)
ax2.set_ylabel('Functions',fontsize=16)
ax2.tick_params(labelsize=12)
ax2.legend(prop={"size":16},loc='upper center')
plt.xscale('log')
plt.savefig('DF_0')
# Out:
# 100
# 44

# %%
from scipy.special import gamma, factorial
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special

nu_0=0.5#m=0,\alpha=pi/4
sMax=100
#x=np.exp(np.arange(-10,3,0.01))
x=np.arange(0.01,30,0.01)
Error=1e-20

amplitude=np.sqrt(2*nu_0/np.tanh(nu_0*np.pi*0.5)/np.pi)
multiplication=1
DG_1j_nu_0=0
for s in np.arange(0,sMax+1):
    multiplication=multiplication*(s**2+nu_0**2)
    phi_nu_0_s=np.angle(gamma(1+s+1j*nu_0))
    derivative=nu_0/2*np.cos(nu_0*np.log(x/2)-phi_nu_0_s)+s*np.sin(nu_0*np.log(x/2)-phi_nu_0_s)
    Sum=(-1)**s*(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)*2/x*derivative
    DG_1j_nu_0=DG_1j_nu_0+Sum
    if(np.size(Sum)==1):
            Sum=np.append(Sum,0)
    if(max(abs(Sum))<Error):
        break
if(s==sMax):
    print("DG_1j_nu_0 don't converge")
DG_1j_nu_0=amplitude*DG_1j_nu_0

print(sMax)
print(s)
plt.plot(x[30:],DG_1j_nu_0[30:],label='$dG_{0.5i}(x)/dx$')
plt.plot(x,(special.jn(0,x)-special.jn(2,x))*0.5,label='$dJ_{1}(x)/dx$')
plt.legend(prop={"size":16})
plt.xlabel('x',fontsize=16)
plt.ylabel('Special Functions',fontsize=16)
#plt.xscale('log')
# Out:
# 100
# 59
# Text(0, 0.5, 'Special Functions')

# %%
from scipy.special import gamma, factorial
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special

nu_0=0.5#m=0,\alpha=pi/4
sMax=100

x1=np.exp(np.arange(-1,0.1,0.01))
x2=np.arange(1,20,0.01)
x=np.append(x1,x2)
Error=1e-20

amplitude=np.sqrt(2*nu_0/np.tanh(nu_0*np.pi*0.5)/np.pi)
multiplication=1
DG_1j_nu_0=0
for s in np.arange(0,sMax+1):
    multiplication=multiplication*(s**2+nu_0**2)
    phi_nu_0_s=np.angle(gamma(1+s+1j*nu_0))
    derivative=nu_0/2*np.cos(nu_0*np.log(x/2)-phi_nu_0_s)+s*np.sin(nu_0*np.log(x/2)-phi_nu_0_s)
    Sum=(-1)**s*(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)*2/x*derivative
    DG_1j_nu_0=DG_1j_nu_0+Sum
    if(np.size(Sum)==1):
            Sum=np.append(Sum,0)
    if(max(abs(Sum))<Error):
        break
if(s==sMax):
    print("DG_1j_nu_0 don't converge")
DG_1j_nu_0=amplitude*DG_1j_nu_0

print(sMax)
print(s)

fig = plt.figure()
fig.set_size_inches(8,6)

left, bottom, width, height = 0.15,0.15,0.8,0.8
ax1 = fig.add_axes([left,bottom,width,height])
ax1.plot(x,DG_1j_nu_0,label='$dG_{0.5i}(x)/dx$')
ax1.plot(x,(special.jn(0,x)-special.jn(2,x))*0.5,label='$dJ_{1}(x)/dx$')
ax1.legend(prop={"size":16},loc='lower right')
ax1.set_xlabel('x',fontsize=16)
ax1.set_ylabel('Functions',fontsize=16)
ax1.set_ylim([-1.5,3])
ax1.tick_params(labelsize=12)

left, bottom, width, height = 0.4,0.53,0.4,0.4
ax2 = fig.add_axes([left,bottom,width,height])
ax2.plot(x,DG_1j_nu_0)
ax2.plot(x,2/x,'r',label='2/x')
ax2.set_xlabel('x',fontsize=16)
ax2.set_ylabel('Functions',fontsize=16)
ax2.tick_params(labelsize=12)
ax2.legend(prop={"size":16},loc='upper center')
plt.xscale('log')
plt.savefig('dG_0.5i.pdf')
# Out:
# 100
# 44

# %%
from scipy.special import gamma, factorial
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special

nu_0=0.5#m=0,\alpha=pi/4
sMax=100
x=np.arange(1,30,0.01)
xNum=np.size(x)
Error=1e-20

amplitude=-np.sqrt(nu_0*np.pi/np.sinh(nu_0*np.pi))
multiplication=1
DK_1j_nu_0=0
for s in np.arange(0,sMax+1):
    multiplication=multiplication*(s**2+nu_0**2)
    phi_nu_0_s=np.angle(gamma(1+s+1j*nu_0))
    derivative=nu_0/2*np.cos(nu_0*np.log(x/2)-phi_nu_0_s)+s*np.sin(nu_0*np.log(x/2)-phi_nu_0_s)
    Sum=(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)*2/x*derivative
    DK_1j_nu_0=DK_1j_nu_0+Sum
    if(np.size(Sum)==1):
            Sum=np.append(Sum,0)
    if(max(abs(Sum))<Error):
        break
if(s==sMax):
    print("DK_1j_nu_0 don't converge")
DK_1j_nu_0=amplitude*DK_1j_nu_0
K_exp=np.exp(-x)

print(sMax)
print(s)
plt.plot(x,DK_1j_nu_0,label='$dK_{0.5i}(x)/dx$')
plt.plot(x[30:xNum],K_exp[30:xNum],label=r'Exp(-x)')
plt.legend(prop={"size":16})
plt.xlabel('x',fontsize=16)
plt.ylabel('Functions',fontsize=16)
# Out:
# 100
# 59
# Text(0, 0.5, 'Functions')

# %%
from scipy.special import gamma, factorial
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special

nu_0=0.5#m=0,\alpha=pi/4
sMax=100

x1=np.exp(np.arange(-4,0.1,0.01))
x2=np.arange(1,20,0.01)
x=np.append(x1,x2)
xNum=np.size(x)

Error=1e-20

amplitude=-np.sqrt(nu_0*np.pi/np.sinh(nu_0*np.pi))
multiplication=1
DK_1j_nu_0=0
for s in np.arange(0,sMax+1):
    multiplication=multiplication*(s**2+nu_0**2)
    phi_nu_0_s=np.angle(gamma(1+s+1j*nu_0))
    derivative=nu_0/2*np.cos(nu_0*np.log(x/2)-phi_nu_0_s)+s*np.sin(nu_0*np.log(x/2)-phi_nu_0_s)
    Sum=(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)*2/x*derivative
    DK_1j_nu_0=DK_1j_nu_0+Sum
    if(np.size(Sum)==1):
            Sum=np.append(Sum,0)
    if(max(abs(Sum))<Error):
        break
if(s==sMax):
    print("DK_1j_nu_0 don't converge")
DK_1j_nu_0=amplitude*DK_1j_nu_0
K_exp=np.exp(-x)

print(sMax)
print(s)

fig = plt.figure()
fig.set_size_inches(8,6)

left, bottom, width, height = 0.15,0.15,0.8,0.8
ax1 = fig.add_axes([left,bottom,width,height])
ax1.plot(x[50:xNum],DK_1j_nu_0[50:xNum],label='$dK_{0.5i}(x)/dx$')
ax1.plot(x[50:xNum],K_exp[50:xNum],label='Exp(-x)')
ax1.legend(prop={"size":16},loc='lower right')
ax1.set_xlabel('x',fontsize=16)
ax1.set_ylabel('Functions',fontsize=16)
#ax1.set_ylim([-1.8,3.8])
ax1.tick_params(labelsize=12)

left, bottom, width, height = 0.4,0.53,0.4,0.4
ax2 = fig.add_axes([left,bottom,width,height])
ax2.plot(x[0:xNum-300],DK_1j_nu_0[0:xNum-300])
ax2.plot(x,1/2/x,'r',label='1/2x')
ax2.set_xlabel('x',fontsize=16)
ax2.set_ylabel('Functions',fontsize=16)
ax2.tick_params(labelsize=12)
ax2.legend(prop={"size":16},loc='upper center')
plt.xscale('log')
plt.savefig('DK_0.5i.pdf')
# Out:
# 100
# 44

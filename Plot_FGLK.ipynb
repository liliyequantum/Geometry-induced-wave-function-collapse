# %%
from scipy.special import gamma, factorial
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special

nu_0=1#m=0,\alpha=pi/4
sMax=100
x=np.arange(0.01,35,0.01)
Error=1e-20

amplitude=np.sqrt(2*nu_0*np.tanh(nu_0*np.pi*0.5)/np.pi)
multiplication=1
F_1j_nu_0=0
for s in np.arange(0,sMax+1):
    multiplication=multiplication*(s**2+nu_0**2)
    phi_nu_0_s=np.angle(gamma(1+s+1j*nu_0))
    Sum=(-1)**s*np.cos(nu_0*np.log(x/2)-phi_nu_0_s)*(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)
    F_1j_nu_0=F_1j_nu_0+Sum
    if(np.size(Sum)==1):
                Sum=np.append(Sum,0)
    if(max(abs(Sum))<Error):
        break
if(s==sMax):
    print("F_1j_nu_0 don't converge")
F_1j_nu_0=amplitude*F_1j_nu_0

print(sMax)
print(s)
plt.plot(x,F_1j_nu_0,label='$F_{0.5i}(x)$')
plt.plot(x,special.jn(0,x),label='$J_{0}(x)$')
plt.legend(prop={"size":16})
plt.xlabel('x',fontsize=16)
plt.ylabel('Special Functions',fontsize=16)
# Out:
# <ipython-input-16-0e058cc1a074>:15: RuntimeWarning: overflow encountered in long_scalars
#   multiplication=multiplication*(s**2+nu_0**2)
# <ipython-input-16-0e058cc1a074>:17: RuntimeWarning: invalid value encountered in sqrt
#   Sum=(-1)**s*np.cos(nu_0*np.log(x/2)-phi_nu_0_s)*(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-16-0e058cc1a074> in <module>
#      15     multiplication=multiplication*(s**2+nu_0**2)
#      16     phi_nu_0_s=np.angle(gamma(1+s+1j*nu_0))
# ---> 17     Sum=(-1)**s*np.cos(nu_0*np.log(x/2)-phi_nu_0_s)*(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)
#      18     F_1j_nu_0=F_1j_nu_0+Sum
#      19     if(np.size(Sum)==1):
#
# ZeroDivisionError: float division by zero

# %%
from scipy.special import gamma, factorial
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special

alpha=np.array([0.4,0.5,0.6,0.8,0.9])*np.pi/2
tilde_alpha=np.sqrt(1-np.sin(alpha)**2)*0.5/np.sin(alpha)
print(tilde_alpha)
nu_0=tilde_alpha[4]#m=0,\alpha=pi/4
sMax=100
x=np.arange(0.01,35,0.01)
Error=1e-20

amplitude=np.sqrt(2*nu_0*np.tanh(nu_0*np.pi*0.5)/np.pi)
multiplication=1
F_1j_nu_0=0
for s in np.arange(0,sMax+1):
    multiplication=multiplication*(s**2+nu_0**2)
    phi_nu_0_s=np.angle(gamma(1+s+1j*nu_0))
    Sum=(-1)**s*np.cos(nu_0*np.log(x/2)-phi_nu_0_s)*(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)
    F_1j_nu_0=F_1j_nu_0+Sum
    if(np.size(Sum)==1):
                Sum=np.append(Sum,0)
    if(max(abs(Sum))<Error):
        break
if(s==sMax):
    print("F_1j_nu_0 don't converge")
F_1j_nu_0=amplitude*F_1j_nu_0

print(sMax)
print(s)
plt.plot(x,F_1j_nu_0,label='$F_{0.5i}(x)$')
plt.plot(x,special.jn(0,x),label='$J_{0}(x)$')
plt.legend(prop={"size":16})
plt.xlabel('x',fontsize=16)
plt.ylabel('Special Functions',fontsize=16)
# Out:
# [0.68819096 0.5        0.36327126 0.16245985 0.07919222]
# 100
# 66
# Text(0, 0.5, 'Special Functions')

# %%
from scipy.special import gamma, factorial
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special

nu_0=0.5#m=0,\alpha=pi/4
sMax=100

x1=np.exp(np.arange(-80,0.1,0.01))
x2=np.arange(1,20,0.01)
x=np.append(x1,x2)
Error=1e-20

amplitude=np.sqrt(2*nu_0*np.tanh(nu_0*np.pi*0.5)/np.pi)
multiplication=1
F_1j_nu_0=0
for s in np.arange(0,sMax+1):
    multiplication=multiplication*(s**2+nu_0**2)
    phi_nu_0_s=np.angle(gamma(1+s+1j*nu_0))
    Sum=(-1)**s*np.cos(nu_0*np.log(x/2)-phi_nu_0_s)*(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)
    F_1j_nu_0=F_1j_nu_0+Sum
    if(np.size(Sum)==1):
                Sum=np.append(Sum,0)
    if(max(abs(Sum))<Error):
        break
if(s==sMax):
    print("F_1j_nu_0 don't converge")
F_1j_nu_0=amplitude*F_1j_nu_0

print(sMax)
print(s)

fig = plt.figure()
fig.set_size_inches(8, 6)

left, bottom, width, height = 0.15,0.15,0.8,0.8
ax1 = fig.add_axes([left,bottom,width,height])
ax1.plot(x,F_1j_nu_0,label='$F_{0.5i}(x)$')
ax1.plot(x,special.jn(0,x),label='$J_{0}(x)$')
ax1.legend(prop={"size":16},loc='lower right')
ax1.set_xlabel('x',fontsize=16)
ax1.set_ylabel('Functions',fontsize=16)
ax1.set_ylim([-1,2.2])
ax1.tick_params(labelsize=12)

left, bottom, width, height = 0.53,0.53,0.4,0.4
ax2 = fig.add_axes([left,bottom,width,height])
ax2.plot(x,F_1j_nu_0)
ax2.plot(x,special.jn(0,x))
ax2.set_xlabel('x',fontsize=16)
ax2.set_ylabel('Functions',fontsize=16)
ax2.tick_params(labelsize=12)
plt.xscale('log')
plt.savefig('F_0.5.pdf')
# Out:
# 100
# 44

# %%
from scipy.special import gamma, factorial
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special

nu_0=0.5#m=0,\alpha=pi/4
sMax=100
x=np.arange(0.01,30,0.01)
Error=1e-20

amplitude=np.sqrt(2*nu_0/np.tanh(nu_0*np.pi*0.5)/np.pi)
multiplication=1
G_1j_nu_0=0
for s in np.arange(0,sMax+1):
    multiplication=multiplication*(s**2+nu_0**2)
    phi_nu_0_s=np.angle(gamma(1+s+1j*nu_0))
    Sum=(-1)**s*np.sin(nu_0*np.log(x/2)-phi_nu_0_s)*(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)
    G_1j_nu_0=G_1j_nu_0+Sum
    if(np.size(Sum)==1):
                Sum=np.append(Sum,0)
    if(max(abs(Sum))<Error):
        break
if(s==sMax):
    print("G_1j_nu_0 don't converge")
G_1j_nu_0=amplitude*G_1j_nu_0

print(sMax)
print(s)
plt.plot(x,G_1j_nu_0,label='$G_{0.5i}(x)$')
plt.plot(x,special.jn(1,x),label='$J_{1}(x)$')
plt.legend(prop={"size":16})
plt.xlabel('x',fontsize=16)
plt.ylabel('Special Functions',fontsize=16)
# Out:
# 100
# 58
# Text(0, 0.5, 'Special Functions')

# %%
from scipy.special import gamma, factorial
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special

alpha=np.array([0.4,0.5,0.6,0.8,0.9])*np.pi/2
tilde_alpha=np.sqrt(1-np.sin(alpha)**2)*0.5/np.sin(alpha)
print(tilde_alpha)
nu_0=tilde_alpha[4]#m=0,\alpha=pi/4
sMax=100
x=np.arange(0.01,35,0.01)
Error=1e-20

amplitude=np.sqrt(2*nu_0/np.tanh(nu_0*np.pi*0.5)/np.pi)
multiplication=1
G_1j_nu_0=0
for s in np.arange(0,sMax+1):
    multiplication=multiplication*(s**2+nu_0**2)
    phi_nu_0_s=np.angle(gamma(1+s+1j*nu_0))
    Sum=(-1)**s*np.sin(nu_0*np.log(x/2)-phi_nu_0_s)*(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)
    G_1j_nu_0=G_1j_nu_0+Sum
    if(np.size(Sum)==1):
                Sum=np.append(Sum,0)
    if(max(abs(Sum))<Error):
        break
if(s==sMax):
    print("G_1j_nu_0 don't converge")
G_1j_nu_0=amplitude*G_1j_nu_0

print(sMax)
print(s)
plt.plot(x,G_1j_nu_0,label='$G_{0.5i}(x)$')
plt.plot(x,special.jn(1,x),label='$J_{1}(x)$')
plt.legend(prop={"size":16})
plt.xlabel('x',fontsize=16)
plt.ylabel('Special Functions',fontsize=16)
# Out:
# [0.68819096 0.5        0.36327126 0.16245985 0.07919222]
# 100
# 65
# Text(0, 0.5, 'Special Functions')

# %%
from scipy.special import gamma, factorial
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special

nu_0=0.5#m=0,\alpha=pi/4
sMax=100

x1=np.exp(np.arange(-80,0.1,0.01))
x2=np.arange(1,20,0.01)
x=np.append(x1,x2)
Error=1e-20

amplitude=np.sqrt(2*nu_0/np.tanh(nu_0*np.pi*0.5)/np.pi)
multiplication=1
G_1j_nu_0=0
for s in np.arange(0,sMax+1):
    multiplication=multiplication*(s**2+nu_0**2)
    phi_nu_0_s=np.angle(gamma(1+s+1j*nu_0))
    Sum=(-1)**s*np.sin(nu_0*np.log(x/2)-phi_nu_0_s)*(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)
    G_1j_nu_0=G_1j_nu_0+Sum
    if(np.size(Sum)==1):
                Sum=np.append(Sum,0)
    if(max(abs(Sum))<Error):
        break
if(s==sMax):
    print("G_1j_nu_0 don't converge")
G_1j_nu_0=amplitude*G_1j_nu_0

print(sMax)
print(s)

fig = plt.figure()
fig.set_size_inches(8, 6)

left, bottom, width, height = 0.15,0.15,0.8,0.8
ax1 = fig.add_axes([left,bottom,width,height])
ax1.plot(x,G_1j_nu_0,label='$G_{0.5i}(x)$')
ax1.plot(x,special.jn(1,x),label='$J_{1}(x)$')
ax1.legend(prop={"size":16},loc='lower right')
ax1.set_xlabel('x',fontsize=16)
ax1.set_ylabel('Functions',fontsize=16)
ax1.set_ylim([-1.5,3])
ax1.tick_params(labelsize=12)

left, bottom, width, height = 0.45,0.53,0.4,0.4
ax2 = fig.add_axes([left,bottom,width,height])
ax2.plot(x,G_1j_nu_0)
ax2.plot(x,special.jn(1,x))
ax2.set_xlabel('x',fontsize=16)
ax2.set_ylabel('Functions',fontsize=16)
ax2.tick_params(labelsize=12)
plt.xscale('log')
plt.savefig('G_0.5.pdf')
# Out:
# 100
# 44

# %%
from scipy.special import gamma, factorial
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special

nu_0=0.5#m=0,\alpha=pi/4
sMax=100
x=np.arange(1,10,0.01)
Error=1e-20

amplitude=np.sqrt(nu_0*np.pi/np.sinh(nu_0*np.pi))
multiplication=1
L_1j_nu_0=0
for s in np.arange(0,sMax+1):
    multiplication=multiplication*(s**2+nu_0**2)
    phi_nu_0_s=np.angle(gamma(1+s+1j*nu_0))
    Sum=np.cos(nu_0*np.log(x/2)-phi_nu_0_s)*(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)
    L_1j_nu_0=L_1j_nu_0+Sum
    if(np.size(Sum)==1):
                Sum=np.append(Sum,0)
    if(max(abs(Sum))<Error):
        break
if(s==sMax):
    print("L_1j_nu_0 don't converge")
L_1j_nu_0=amplitude*L_1j_nu_0
L_exp=1/np.sinh(nu_0*np.pi)*np.sqrt(np.pi/2/x)*np.exp(x)

print(sMax)
print(s)
plt.plot(x,L_1j_nu_0,label='$L_{0.5i}(x)$')
plt.plot(x,L_exp,label=r'$\frac{1}{\sinh\left(\nu\pi\right)}\left(\frac{\pi}{2x}\right)^{1/2}e^{x}$')
plt.legend(prop={"size":16})
plt.xlabel('x',fontsize=16)
plt.ylabel('Functions',fontsize=16)
# Out:
# 100
# 29
# Text(0, 0.5, 'Functions')

# %%
from scipy.special import gamma, factorial
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special

nu_0=0.5#m=0,\alpha=pi/4
sMax=100

x1=np.arange(1,4.5,0.01)
x2=np.exp(np.arange(-80,0.01,0.01))
x=np.append(x2,x1)
xNum=np.size(x)

Error=1e-20

amplitude=np.sqrt(nu_0*np.pi/np.sinh(nu_0*np.pi))
multiplication=1
L_1j_nu_0=0
for s in np.arange(0,sMax+1):
    multiplication=multiplication*(s**2+nu_0**2)
    phi_nu_0_s=np.angle(gamma(1+s+1j*nu_0))
    Sum=np.cos(nu_0*np.log(x/2)-phi_nu_0_s)*(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)
    L_1j_nu_0=L_1j_nu_0+Sum
    if(np.size(Sum)==1):
                Sum=np.append(Sum,0)
    if(max(abs(Sum))<Error):
        break
if(s==sMax):
    print("L_1j_nu_0 don't converge")
L_1j_nu_0=amplitude*L_1j_nu_0
L_exp=1/np.sinh(nu_0*np.pi)*np.sqrt(np.pi/2/x1)*np.exp(x1)

print(sMax)
print(s)

fig = plt.figure()
fig.set_size_inches(8,6)

left, bottom, width, height = 0.15,0.15,0.8,0.8
ax1 = fig.add_axes([left,bottom,width,height])
ax1.plot(x,L_1j_nu_0,label='$L_{0.5i}(x)$')
ax1.plot(x1,L_exp,label=r'$\frac{1}{\sinh\left(\nu\pi\right)}\left(\frac{\pi}{2x}\right)^{1/2}e^{x}$')
ax1.legend(prop={"size":16},loc='lower right')
ax1.set_xlabel('x',fontsize=16)
ax1.set_ylabel('Functions',fontsize=16)
#ax1.set_ylim([-1,2.2])
ax1.tick_params(labelsize=12)

left, bottom, width, height = 0.24,0.53,0.4,0.4
ax2 = fig.add_axes([left,bottom,width,height])
ax2.plot(x[0:xNum-300],L_1j_nu_0[0:xNum-300])
ax2.plot(x1,L_exp)
ax2.set_xlabel('x',fontsize=16)
ax2.set_ylabel('Functions',fontsize=16)
ax2.tick_params(labelsize=12)
plt.xscale('log')
plt.savefig('L_0.5.pdf')
# Out:
# 100
# 19

# %%
from scipy.special import gamma, factorial
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special

nu_0=0.5#m=0,\alpha=pi/4
sMax=100
x=np.arange(0.01,30,0.01)
xNum=np.size(x)
Error=1e-20

amplitude=-np.sqrt(nu_0*np.pi/np.sinh(nu_0*np.pi))
multiplication=1
K_1j_nu_0=0
for s in np.arange(0,sMax+1):
    multiplication=multiplication*(s**2+nu_0**2)
    phi_nu_0_s=np.angle(gamma(1+s+1j*nu_0))
    Sum=np.sin(nu_0*np.log(x/2)-phi_nu_0_s)*(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)
    K_1j_nu_0=K_1j_nu_0+Sum
    if(np.size(Sum)==1):
                Sum=np.append(Sum,0)
    if(max(abs(Sum))<Error):
        break
if(s==sMax):
    print("K_1j_nu_0 don't converge")
K_1j_nu_0=amplitude*K_1j_nu_0
K_exp=np.sqrt(np.pi/2/x)*np.exp(-x)

print(sMax)
print(s)
plt.plot(x,K_1j_nu_0,label='$K_{0.5i}(x)$')
plt.plot(x[30:xNum],K_exp[30:xNum],label=r'$\left(\frac{\pi}{2x}\right)^{1/2}e^{-x}$')
plt.legend(prop={"size":16})
plt.xlabel('x',fontsize=16)
plt.ylabel('Functions',fontsize=16)
# Out:
# 100
# 58
# Text(0, 0.5, 'Functions')

# %%
from scipy.special import gamma, factorial
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special

nu_0=0.5#m=0,\alpha=pi/4
sMax=100

x1=np.arange(0.2,30,0.01)
x2=np.exp(np.arange(-80,0.01,0.01))
x=np.append(x2,x1)
xNum=np.size(x)

Error=1e-20

amplitude=-np.sqrt(nu_0*np.pi/np.sinh(nu_0*np.pi))
multiplication=1
K_1j_nu_0=0
for s in np.arange(0,sMax+1):
    multiplication=multiplication*(s**2+nu_0**2)
    phi_nu_0_s=np.angle(gamma(1+s+1j*nu_0))
    Sum=np.sin(nu_0*np.log(x/2)-phi_nu_0_s)*(x**2/4)**(s)/np.math.factorial(s)/np.sqrt(multiplication)
    K_1j_nu_0=K_1j_nu_0+Sum
    if(np.size(Sum)==1):
                Sum=np.append(Sum,0)
    if(max(abs(Sum))<Error):
        break
if(s==sMax):
    print("K_1j_nu_0 don't converge")
K_1j_nu_0=amplitude*K_1j_nu_0
K_exp=np.sqrt(np.pi/2/x1)*np.exp(-x1)

print(sMax)
print(s)

fig = plt.figure()
fig.set_size_inches(8,6)

left, bottom, width, height = 0.15,0.15,0.8,0.8
ax1 = fig.add_axes([left,bottom,width,height])
ax1.plot(x,K_1j_nu_0,label='$K_{0.5i}(x)$')
ax1.plot(x1,K_exp,label=r'$\left(\frac{\pi}{2x}\right)^{1/2}e^{-x}$')
ax1.legend(prop={"size":16},loc='lower right')
ax1.set_xlabel('x',fontsize=16)
ax1.set_ylabel('Functions',fontsize=16)
ax1.set_ylim([-1.8,3.8])
ax1.tick_params(labelsize=12)

left, bottom, width, height = 0.43,0.53,0.4,0.4
ax2 = fig.add_axes([left,bottom,width,height])
ax2.plot(x[0:xNum-300],K_1j_nu_0[0:xNum-300])
ax2.plot(x1,K_exp)
ax2.set_xlabel('x',fontsize=16)
ax2.set_ylabel('Functions',fontsize=16)
ax2.tick_params(labelsize=12)
plt.xscale('log')
plt.savefig('K_0.5.pdf')
# Out:
# 100
# 58

# %%
import numpy as np

np.sinh([0,1.4])
# Out:
# array([0.       , 1.9043015])

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import gamma, factorial

nu=0
Error=1e-5
kMax=100

x=np.arange(0.01,50,0.01)
J_nu=0
for k in np.arange(0,kMax+1):
    Sum=(-1)**k*(x**2/4)**k*(x/2)**nu/np.math.factorial(k)/gamma(k+nu+1)
    J_nu=J_nu+Sum
    if(max(abs(Sum))<Error):
        break
if(k==kMax):
    print("J_nu don't converge!")
print(kMax)
print(k)
plt.plot(x,J_nu)
# Out:
# 100
# 71

# %%
import matplotlib.pyplot as plt
 
fig = plt.figure()
 
x = [1,2,3,4,5,6,7]
y = [1,3,4,2,5,8,6]
 
 
left, bottom, width, height = 0.1,0.1,0.8,0.8
ax1 = fig.add_axes([left,bottom,width,height])
ax1.plot(x,y,'r')
ax1.set_xlabel("x")
ax1.set_ylabel("y")
ax1.set_title('title')
 
left, bottom, width, height = 0.2,0.6,0.25,0.25
ax2 = fig.add_axes([left,bottom,width,height])
ax2.plot(x,y,'g')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_title('title inside1')
 
left, bottom, width, height = 0.6,0.2,0.25,0.25
plt.axes([left,bottom,width,height])
plt.plot(y[::-1],x,'b')
plt.xlabel('x')
plt.ylabel('y')
plt.title('tile inside2')
 
plt.show()

# %%
x=[1,2,3]
print(x[0:2])
# Out:
# [1, 2]
